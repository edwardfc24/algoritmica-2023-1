# %%
from sklearn import neighbors
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cc_state_sector_grads.csv')

# %%
df.gender = df.gender.map({'M': 0, 'B': 1})
df.state = df.state.map({'United States': 0, 'Alabama': 1})

# %%
df.describe()
# Out:
#              index       stateid        state          year        gender  \
# count  84942.00000  84942.000000  3672.000000  84942.000000  56628.000000
# mean   42470.50000     28.179699     0.470588   2007.565162      0.500000
# std    24520.78762     15.901155     0.499202      3.489043      0.500004
# min        0.00000      0.000000     0.000000   2002.000000      0.000000
# 25%    21235.25000     16.000000     0.000000   2005.000000      0.000000
# 50%    42470.50000     28.000000     0.000000   2008.000000      0.500000
# 75%    63705.75000     41.000000     1.000000   2011.000000      1.000000
# max    84941.00000     56.000000     1.000000   2013.000000      1.000000
#
#          grad_cohort       grad_100       grad_150  grad_100_rate  \
# count   84942.000000   31760.000000   84942.000000   30033.000000
# mean     2308.136658    1346.772733    1058.684703      28.254796
# std     19414.099744    9678.350718    9753.837421      19.921761
# min         0.000000       0.000000       0.000000       0.000000
# 25%         6.000000       3.000000       2.000000      13.100000
# 50%        64.000000      33.500000      20.000000      25.800000
# 75%       561.000000     409.000000     207.000000      41.400000
# max    891211.000000  296553.000000  513263.000000     100.000000
#
#        grad_150_rate  grad_cohort_ct
# count   75623.000000    84942.000000
# mean       39.426019       23.215512
# std        24.626696       92.582082
# min         0.000000        1.000000
# 25%        19.900000        3.000000
# 50%        39.400000        7.000000
# 75%        56.800000       16.000000
# max       100.000000     1180.000000

# %%
df.tail()
# Out:
#        index  stateid  state state_abbr control   level  year  gender race  \
# 84937  84937        0    0.0         US  Public  2-year  2013     0.0   Ai
# 84938  84938        0    0.0         US  Public  2-year  2013     0.0    B
# 84939  84939        0    0.0         US  Public  2-year  2013     0.0    H
# 84940  84940        0    0.0         US  Public  2-year  2013     0.0    W
# 84941  84941        0    0.0         US  Public  2-year  2013     0.0    X
#
#        cohort  grad_cohort  grad_100  grad_150  grad_100_rate  grad_150_rate  \
# 84937  2y all         3956       NaN       510            NaN           12.9
# 84938  2y all        53531       NaN      5642            NaN           10.5
# 84939  2y all        54952       NaN      8294            NaN           15.1
# 84940  2y all       200074       NaN     43642            NaN           21.8
# 84941  2y all       361735       NaN     68328            NaN           18.9
#
#        grad_cohort_ct
# 84937             926
# 84938             926
# 84939             926
# 84940             926
# 84941             926

# %%
df.head()
# Out:
#    index  stateid  state state_abbr             control   level  year  gender  \
# 0      0        1    1.0         AL  Private for-profit  4-year  2011     1.0
# 1      1        1    1.0         AL  Private for-profit  4-year  2011     1.0
# 2      2        1    1.0         AL  Private for-profit  4-year  2011     1.0
# 3      3        1    1.0         AL  Private for-profit  4-year  2011     1.0
# 4      4        1    1.0         AL  Private for-profit  4-year  2011     1.0
#
#   race   cohort  grad_cohort  grad_100  grad_150  grad_100_rate  \
# 0    A  4y bach            0       0.0         0            NaN
# 1   Ai  4y bach            1       0.0         0            0.0
# 2    B  4y bach           51       2.0         3            3.9
# 3    H  4y bach            1       0.0         0            0.0
# 4    W  4y bach           66      15.0        18           22.7
#
#    grad_150_rate  grad_cohort_ct
# 0            NaN               9
# 1            0.0               9
# 2            5.9               9
# 3            0.0               9
# 4           27.3               9

# %%
df.columns
# Out:
# Index(['index', 'stateid', 'state', 'state_abbr', 'control', 'level', 'year',
#        'gender', 'race', 'cohort', 'grad_cohort', 'grad_100', 'grad_150',
#        'grad_100_rate', 'grad_150_rate', 'grad_cohort_ct'],
#       dtype='object')

# %%
df.drop('index', axis=1, inplace=True)
df.drop('state', axis=1, inplace=True)
df.drop('state_abbr', axis=1, inplace=True)
df.drop('control', axis=1, inplace=True)
df.drop('level', axis=1, inplace=True)
df.drop('race', axis=1, inplace=True)
df.drop('cohort', axis=1, inplace=True)
df.dropna(axis=1, inplace=True)

# %%
corr = df.corr()
corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_5e40e_row0_col0, #T_5e40e_row1_col1, #T_5e40e_row2_col2, #T_5e40e_row3_col3, #T_5e40e_row4_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_5e40e_row0_col1, #T_5e40e_row0_col2, #T_5e40e_row0_col3, #T_5e40e_row0_col4, #T_5e40e_row4_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_5e40e_row1_col0 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_5e40e_row1_col2 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_5e40e_row1_col3 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_5e40e_row1_col4 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_5e40e_row2_col0 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_5e40e_row2_col1, #T_5e40e_row3_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_5e40e_row2_col3, #T_5e40e_row3_col2 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_5e40e_row2_col4 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_5e40e_row3_col0 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_5e40e_row3_col4 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_5e40e_row4_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_5e40e_row4_col2 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_5e40e_row4_col3 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5e40e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e40e_level0_col0" class="col_heading level0 col0" >stateid</th>
#       <th id="T_5e40e_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_5e40e_level0_col2" class="col_heading level0 col2" >grad_cohort</th>
#       <th id="T_5e40e_level0_col3" class="col_heading level0 col3" >grad_150</th>
#       <th id="T_5e40e_level0_col4" class="col_heading level0 col4" >grad_cohort_ct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e40e_level0_row0" class="row_heading level0 row0" >stateid</th>
#       <td id="T_5e40e_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_5e40e_row0_col1" class="data row0 col1" >-0.007652</td>
#       <td id="T_5e40e_row0_col2" class="data row0 col2" >-0.105286</td>
#       <td id="T_5e40e_row0_col3" class="data row0 col3" >-0.096017</td>
#       <td id="T_5e40e_row0_col4" class="data row0 col4" >-0.219571</td>
#     </tr>
#     <tr>
#       <th id="T_5e40e_level0_row1" class="row_heading level0 row1" >year</th>
#       <td id="T_5e40e_row1_col0" class="data row1 col0" >-0.007652</td>
#       <td id="T_5e40e_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_5e40e_row1_col2" class="data row1 col2" >0.011422</td>
#       <td id="T_5e40e_row1_col3" class="data row1 col3" >0.010314</td>
#       <td id="T_5e40e_row1_col4" class="data row1 col4" >0.035702</td>
#     </tr>
#     <tr>
#       <th id="T_5e40e_level0_row2" class="row_heading level0 row2" >grad_cohort</th>
#       <td id="T_5e40e_row2_col0" class="data row2 col0" >-0.105286</td>
#       <td id="T_5e40e_row2_col1" class="data row2 col1" >0.011422</td>
#       <td id="T_5e40e_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_5e40e_row2_col3" class="data row2 col3" >0.936329</td>
#       <td id="T_5e40e_row2_col4" class="data row2 col4" >0.474092</td>
#     </tr>
#     <tr>
#       <th id="T_5e40e_level0_row3" class="row_heading level0 row3" >grad_150</th>
#       <td id="T_5e40e_row3_col0" class="data row3 col0" >-0.096017</td>
#       <td id="T_5e40e_row3_col1" class="data row3 col1" >0.010314</td>
#       <td id="T_5e40e_row3_col2" class="data row3 col2" >0.936329</td>
#       <td id="T_5e40e_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_5e40e_row3_col4" class="data row3 col4" >0.424453</td>
#     </tr>
#     <tr>
#       <th id="T_5e40e_level0_row4" class="row_heading level0 row4" >grad_cohort_ct</th>
#       <td id="T_5e40e_row4_col0" class="data row4 col0" >-0.219571</td>
#       <td id="T_5e40e_row4_col1" class="data row4 col1" >0.035702</td>
#       <td id="T_5e40e_row4_col2" class="data row4 col2" >0.474092</td>
#       <td id="T_5e40e_row4_col3" class="data row4 col3" >0.424453</td>
#       <td id="T_5e40e_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Inicializar el modelo
k_neighbors = neighbors.KNeighborsClassifier()

# %%
# Preparar la data para entrenar el modelo
data_x = df.drop(['stateid', 'grad_cohort', 'year','grad_cohort_ct'], axis='columns')
data_y = df.grad_150

# %%
print(data_x)
print(data_y)
# Out:
#        grad_150
# 0             0
# 1             0
# 2             3
# 3             0
# 4            18
# ...         ...
# 84937       510
# 84938      5642
# 84939      8294
# 84940     43642
# 84941     68328
#
# [84942 rows x 1 columns]
# 0            0
# 1            0
# 2            3
# 3            0
# 4           18
#          ...
# 84937      510
# 84938     5642
# 84939     8294
# 84940    43642
# 84941    68328
# Name: grad_150, Length: 84942, dtype: int64

# %%
train_x, test_x, train_y, test_y = train_test_split(data_x, data_y, test_size=0.1)

# %%
# Entrenar el modelo
k_neighbors.fit(train_x, train_y)
# Out:
# KNeighborsClassifier()

# %%
# Medir la confianza de nuestro modelo
print(f'Score: {round(k_neighbors.score(test_x, test_y), 4) * 100}%')
# Out:
# Score: 92.11%

# %%
# Ahora aplicamos el método predict para encontrar una nueva etiqueta
year = 2013
predicted = k_neighbors.predict([[year]])
# Out:
# c:\Users\USUARIO\Desktop\TareaAlgoritmica\TareaAlgoritmica\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
print(f'La persona salio en el año {year}')
# Out:
# La persona salio en el año 2013
