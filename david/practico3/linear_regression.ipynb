# %%
from sklearn.model_selection import train_test_split
from sklearn import linear_model

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('California_Houses.csv')

# %%
df.count()
# Out:
# Median_House_Value          20640
# Median_Income               20640
# Median_Age                  20640
# Tot_Rooms                   20640
# Tot_Bedrooms                20640
# Population                  20640
# Households                  20640
# Latitude                    20640
# Longitude                   20640
# Distance_to_coast           20640
# Distance_to_LA              20640
# Distance_to_SanDiego        20640
# Distance_to_SanJose         20640
# Distance_to_SanFrancisco    20640
# dtype: int64

# %%
df.head(10)
# Out:
#    Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms
# 0            452600.0         8.3252          41        880           129  \
# 1            358500.0         8.3014          21       7099          1106
# 2            352100.0         7.2574          52       1467           190
# 3            341300.0         5.6431          52       1274           235
# 4            342200.0         3.8462          52       1627           280
# 5            269700.0         4.0368          52        919           213
# 6            299200.0         3.6591          52       2535           489
# 7            241400.0         3.1200          52       3104           687
# 8            226700.0         2.0804          42       2555           665
# 9            261100.0         3.6912          52       3549           707
#
#    Population  Households  Latitude  Longitude  Distance_to_coast
# 0         322         126     37.88    -122.23        9263.040773  \
# 1        2401        1138     37.86    -122.22       10225.733072
# 2         496         177     37.85    -122.24        8259.085109
# 3         558         219     37.85    -122.25        7768.086571
# 4         565         259     37.85    -122.25        7768.086571
# 5         413         193     37.85    -122.25        7768.086571
# 6        1094         514     37.84    -122.25        6843.020847
# 7        1157         647     37.84    -122.25        6843.020847
# 8        1206         595     37.84    -122.26        6363.948013
# 9        1551         714     37.84    -122.25        6843.020847
#
#    Distance_to_LA  Distance_to_SanDiego  Distance_to_SanJose
# 0   556529.158342         735501.806984         67432.517001  \
# 1   554279.850069         733236.884360         65049.908574
# 2   554610.717069         733525.682937         64867.289833
# 3   555194.266086         734095.290744         65287.138412
# 4   555194.266086         734095.290744         65287.138412
# 5   555194.266086         734095.290744         65287.138412
# 6   554364.406936         733249.808578         64315.991742
# 7   554364.406936         733249.808578         64315.991742
# 8   554949.749519         733820.824419         64751.463863
# 9   554364.406936         733249.808578         64315.991742
#
#    Distance_to_SanFrancisco
# 0              21250.213767
# 1              20880.600400
# 2              18811.487450
# 3              18031.047568
# 4              18031.047568
# 5              18031.047568
# 6              17538.209972
# 7              17538.209972
# 8              16744.406584
# 9              17538.209972

# %%
df.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_af974_row0_col0, #T_af974_row1_col1, #T_af974_row2_col2, #T_af974_row3_col3, #T_af974_row4_col4, #T_af974_row5_col5, #T_af974_row6_col6, #T_af974_row7_col7, #T_af974_row8_col8, #T_af974_row9_col9, #T_af974_row10_col10, #T_af974_row11_col11, #T_af974_row12_col12, #T_af974_row13_col13 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_af974_row0_col1 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_af974_row0_col2 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_af974_row0_col3, #T_af974_row6_col0 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_af974_row0_col4 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_af974_row0_col5 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_af974_row0_col6 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_af974_row0_col7, #T_af974_row0_col10 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_af974_row0_col8, #T_af974_row0_col13, #T_af974_row11_col9 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_af974_row0_col9, #T_af974_row2_col3, #T_af974_row2_col4, #T_af974_row2_col5, #T_af974_row2_col6, #T_af974_row3_col2, #T_af974_row8_col7, #T_af974_row8_col10, #T_af974_row8_col11, #T_af974_row9_col0, #T_af974_row9_col1, #T_af974_row11_col8, #T_af974_row11_col12, #T_af974_row11_col13 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_af974_row0_col11, #T_af974_row4_col10, #T_af974_row6_col7 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_af974_row0_col12, #T_af974_row4_col7, #T_af974_row9_col13 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_af974_row1_col0 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_af974_row1_col2, #T_af974_row7_col6, #T_af974_row11_col6, #T_af974_row13_col1 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_af974_row1_col3, #T_af974_row3_col0, #T_af974_row5_col10 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_af974_row1_col4, #T_af974_row11_col3 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_af974_row1_col5, #T_af974_row10_col0 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_af974_row1_col6, #T_af974_row10_col2 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_af974_row1_col7, #T_af974_row6_col10 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_af974_row1_col8 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_af974_row1_col9 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_af974_row1_col10, #T_af974_row2_col8 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_af974_row1_col11, #T_af974_row3_col7, #T_af974_row3_col10 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_af974_row1_col12 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_af974_row1_col13, #T_af974_row3_col11 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_af974_row2_col0 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_af974_row2_col1, #T_af974_row9_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_af974_row2_col7, #T_af974_row3_col12 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_af974_row2_col9, #T_af974_row12_col1 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_af974_row2_col10, #T_af974_row4_col11, #T_af974_row6_col11, #T_af974_row10_col9 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_af974_row2_col11, #T_af974_row6_col13 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_af974_row2_col12, #T_af974_row5_col7 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_af974_row2_col13, #T_af974_row9_col12 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_af974_row3_col1, #T_af974_row4_col0 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_af974_row3_col4, #T_af974_row4_col3 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_af974_row3_col5 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_af974_row3_col6 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_af974_row3_col8, #T_af974_row4_col13, #T_af974_row5_col12 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_af974_row3_col9 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_af974_row3_col13 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_af974_row4_col1, #T_af974_row13_col2 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_af974_row4_col2 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_af974_row4_col5 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_af974_row4_col6, #T_af974_row6_col4 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_af974_row4_col8, #T_af974_row5_col13, #T_af974_row7_col9 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_af974_row4_col9, #T_af974_row5_col0 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_af974_row4_col12 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_af974_row5_col1, #T_af974_row10_col4, #T_af974_row12_col2 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_af974_row5_col2, #T_af974_row10_col12 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_af974_row5_col3 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_af974_row5_col4 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_af974_row5_col6, #T_af974_row6_col5 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_af974_row5_col8 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_af974_row5_col9, #T_af974_row11_col2, #T_af974_row12_col0, #T_af974_row12_col5, #T_af974_row13_col3 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_af974_row5_col11 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_af974_row6_col1 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_af974_row6_col2, #T_af974_row10_col13 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_af974_row6_col3 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_af974_row6_col8 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_af974_row6_col9, #T_af974_row7_col2, #T_af974_row8_col6 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_af974_row6_col12, #T_af974_row9_col8 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_af974_row7_col0 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_af974_row7_col1 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_af974_row7_col3 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_af974_row7_col4, #T_af974_row11_col4 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_af974_row7_col5, #T_af974_row11_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_af974_row7_col8, #T_af974_row7_col12, #T_af974_row7_col13, #T_af974_row13_col7, #T_af974_row13_col11 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_af974_row7_col10, #T_af974_row10_col7 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_af974_row7_col11, #T_af974_row11_col7, #T_af974_row12_col13, #T_af974_row13_col12 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_af974_row8_col0, #T_af974_row12_col3, #T_af974_row12_col4, #T_af974_row13_col4 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_af974_row8_col1 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_af974_row8_col2, #T_af974_row9_col6, #T_af974_row10_col6 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_af974_row8_col3, #T_af974_row13_col0, #T_af974_row13_col5 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_af974_row8_col4 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_af974_row8_col5 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_af974_row8_col9 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_af974_row8_col12 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_af974_row8_col13, #T_af974_row13_col8 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_af974_row9_col3 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_af974_row9_col4 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_af974_row9_col5 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_af974_row9_col7 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_af974_row9_col10 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_af974_row9_col11 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_af974_row10_col1, #T_af974_row10_col5, #T_af974_row11_col5 {
#   background-color: #e8e4f0;
#   color: #000

# %%
df = df.drop(df.columns[[0,1,2,7,8,9,10,11,12,13]], axis=1)

# %%
df.head()
# Out:
#    Tot_Rooms  Tot_Bedrooms  Population  Households
# 0        880           129         322         126
# 1       7099          1106        2401        1138
# 2       1467           190         496         177
# 3       1274           235         558         219
# 4       1627           280         565         259

# %%
model = linear_model.LinearRegression()

# %%
data_x = df.drop('Population', axis=1)
data_y = df.Population

# %%
train_x, test_x, train_y, test_y = train_test_split(data_x, data_y)

# %%
model.fit(train_x, train_y)
# Out:
# LinearRegression()

# %%
model.score(test_x, test_y)
# Out:
# 0.8466872527073291

# %%
tot_rooms = 880
tot_bedrooms = 129
housefolds = 126
predicted = model.predict([[tot_rooms, tot_bedrooms, housefolds]])
# Out:
# d:\Universidad\Quinto_Semestre\Algoritmica\Practico2\practico_virtualenv\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(f'El grupo de {housefolds} hogares, el cual tiene {tot_rooms} habitaciones de las cuales {tot_bedrooms} dormitorios, tiene {round(predicted[0])} habitantes')
# Out:
# El grupo de 126 hogares, el cual tiene 880 habitaciones de las cuales 129 dormitorios, tiene 446 habitantes
